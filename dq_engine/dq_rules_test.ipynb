# %%
# !git clone https://github.com/shyamaldutta897/dq_bpf.git
# Out:
# Cloning into 'dq_bpf'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 7 (delta 0), reused 7 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), done.

# %%
import sys
sys.path.append('/content/dq_bpf')

# %%
# !ls /content/dq_bpf/utils
# Out:
# __init__.py  spark_session.py

# %%
from utils.spark_session import spark

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://8dd1ccb177c7:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>dq_bpf</code></dd>
#             </dl>
#         </div>
#
#             </div>
